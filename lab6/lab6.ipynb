# %%
#Лабораторная работа №6
#Рахматуллин Камиль Айратович

#Задание №1

class UserAccount():
    def __init__(self, username, email, password):
        self.username = username
        self.email = email
        self.__password = password
    def set_password(self, oldpw, newpw):
      if oldpw == self.__password:
        self.__password = newpw
        print('Password Changed')
      else:
        print('Wrong Password')
    def check_password(self, checkpw):
        return checkpw == self.__password

user1 = UserAccount('kamil', 'email@email.com', 12345)

print(user1.username, user1.email)
try:
    print(user1.__password)
except:
    print('Attribute is not available')


print(user1.check_password(12345))
user1.set_password(00000, 'new password')
user1.set_password(12345, 'new password')
print(user1.check_password(12345))

#Задание 2
print(' ')

class Vehicle():
    def __init__(self, model):
        self.model = model
    def get_info(self):
        return self.model

class Car(Vehicle):
    def __init__(self, model, fuel_type):
        super().__init__(model)
        self.fuel_type = fuel_type
    def get_info(self):
        return super().get_info(), self.fuel_type

vehicle = Vehicle('cool car')
car = Car('cooler car', 'petrol')

print(vehicle.get_info())
print(car.get_info())
# Out:
# kamil email@email.com
# Attribute is not available
# True
# Wrong Password
# Password Changed
# False
#
# cool car
# ('cooler car', 'petrol')
